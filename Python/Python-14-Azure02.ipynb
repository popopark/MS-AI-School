# %%
# !pip install azure-storage-file
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 2.1 MB/s eta 0:00:00
# ...

# %%
from azure.storage.file import FileService

file_service = FileService(account_name='labuser119', account_key='9tRch+54Q4AnUWia0rdDK99M1Op54LqtOCHCnwzpoh58It1coJCIE01csZ+kIUKk1mLvR351vpkW+AStdbiTjA==')

# %%
file_service.create_share('myshare')
# Out:
# True

# %%
file_service.create_directory('myshare', 'sampledir')
# Out:
# True

# %%
from azure.storage.file import ContentSettings
file_service.create_file_from_path(
    'myshare',
    'sampledir',
    'myfile.jpg',
    'Yn.jpg'
)

# %%
# directory 내용의 확인

generator = file_service.list_directories_and_files('myshare')
for file_or_dir in generator:
  print(file_or_dir.name)
# Out:
# myfile
# sampledir

# %%
# 파일을 가져오는 코드
file_service.get_file_to_path('myshare',None,'myfile','Yn_DOWNLOAD.jpeg')

# %%
# snapshot

metadata = {'foo':'bar'}
snapshot = file_service.snapshot_share('myshare', metadata=metadata)

# %%
# 스냅샷이 포함되어 있는 목록을 가지고 와라는 뜻뜻
share = list(file_service.list_shares(include_snapshots=True))

# %%
# 지정된 스냅샷으로 돌아 갈 수 있다.

directories_and_file = list(file_service.list_directories_and_files('myshare',snapshot='2023-04-20T05:48:13.0000000Z'))
for file_or_dir in directories_and_file:
  print(file_or_dir.name)
# Out:
# myfile
# sampledir

# %%
# 스냅샷 파일을 삭제한다.

file_service.delete_share('myshare', snapshot='2023-04-20T05:48:13.0000000Z')
# Out:
# True

# %%
# 스냅샷 삭제

file_service.delete_file('myshare', None, 'myfile')

# %%
# 마이 쉐어 삭제

file_service.delete_share('myshare')
# Out:
# True
