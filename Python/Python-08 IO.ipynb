# %%
# IO (Input/Output)

print(1)
# Out:
# 1

# %%
import sys

print('Welcom to ', 'Python', sep='-', end='!', file = sys.stderr)
# Out:
# Welcom to -Python!

# %%
f = open('test.txt', 'w')

# %%
print('welcome to python', file = f)

# %%
f.close()

# %%
f = open('test.txt','r')

# %%
f.read()
# Out:
# ''

# %%
f.read()
# Out:
# ''

# %%
f.readline()
# Out:
# ''
