# %%
import keras
keras.__version__
# Out:
# '2.12.0'

# %%
from keras.datasets import mnist
(train_images,train_labels),(test_images,test_labels) = mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
# 데이터의 확인 
import matplotlib.pyplot as plt

digit = train_images[4]
plt.imshow(digit, cmap=plt.cm.binary)

# %%
# 신경망을 만드는 부분 

from keras import models
from keras import layers

network = models.Sequential()
network.add(layers.Dense(512,activation='relu',input_shape=(28*28,)))
network.add(layers.Dense(10,activation='softmax'))
network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
# 데이터를 준비하는 부분

train_images = train_images.reshape((60000, 28*28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28*28))
test_images = test_images.astype('float32') / 255

# %%
# 라벨 데이터를 카테고리 데이터로 변환
from tensorflow.keras.utils import to_categorical

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
# 신경망의 학습
network.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 6s 10ms/step - loss: 0.2607 - accuracy: 0.9250
# Epoch 2/5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1061 - accuracy: 0.9691
# Epoch 3/5
# 469/469 [==============================] - 6s 13ms/step - loss: 0.0702 - accuracy: 0.9788
# Epoch 4/5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0517 - accuracy: 0.9847
# Epoch 5/5
# 469/469 [==============================] - 6s 13ms/step - loss: 0.0387 - accuracy: 0.9881

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
print('test acc:', test_acc)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0644 - accuracy: 0.9801
# test acc: 0.9800999760627747

# %%
# IMDB

from keras.datasets import imdb
(train_data,train_labels),(test_data,test_labels) = imdb.load_data(num_words=10000)

# %%
train_data.shape
# Out:
# (25000,)

# %%
train_labels[0:5]
# Out:
# array([1, 0, 0, 1, 0])

# %%
max([max(sequence) for sequence in train_data])
# Out:
# 9999

# %%
# 데이터를 준비
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
  result = np.zeros((len(sequences),dimension))

  print(result.shape)

  for i, sequence in enumerate(sequences):
    result[i, sequence] = 1
  return result

# %%
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)
# Out:
# (25000, 10000)
# (25000, 10000)

# %%
x_train[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
# 라벨 데이터도 실수형으로 
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %%
y_train[0]
# Out:
# 1.0

# %%
# 신경망 제작
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
history = model.fit(partial_x_train, 
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 [==============================] - 3s 78ms/step - loss: 0.5547 - accuracy: 0.7632 - val_loss: 0.4480 - val_accuracy: 0.8288
# Epoch 2/20
# 30/30 [==============================] - 2s 51ms/step - loss: 0.3579 - accuracy: 0.8863 - val_loss: 0.3480 - val_accuracy: 0.8687
# Epoch 3/20
# 30/30 [==============================] - 2s 59ms/step - loss: 0.2642 - accuracy: 0.9165 - val_loss: 0.2998 - val_accuracy: 0.8847
# Epoch 4/20
# 30/30 [==============================] - 2s 66ms/step - loss: 0.2143 - accuracy: 0.9297 - val_loss: 0.2791 - val_accuracy: 0.8886
# Epoch 5/20
# 30/30 [==============================] - 1s 40ms/step - loss: 0.1770 - accuracy: 0.9431 - val_loss: 0.3026 - val_accuracy: 0.8783
# Epoch 6/20
# 30/30 [==============================] - 1s 40ms/step - loss: 0.1547 - accuracy: 0.9510 - val_loss: 0.2827 - val_accuracy: 0.8862
# Epoch 7/20
# 30/30 [==============================] - 1s 40ms/step - loss: 0.1310 - accuracy: 0.9610 - val_loss: 0.2862 - val_accuracy: 0.8853
# Epoch 8/20
# 30/30 [==============================] - 2s 56ms/step - loss: 0.1140 - accuracy: 0.9655 - val_loss: 0.3316 - val_accuracy: 0.8741
# Epoch 9/20
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0999 - accuracy: 0.9715 - val_loss: 0.3106 - val_accuracy: 0.8818
# Epoch 10/20
# 30/30 [==============================] - 1s 42ms/step - loss: 0.0861 - accuracy: 0.9763 - val_loss: 0.3629 - val_accuracy: 0.8700
# Epoch 11/20
# 30/30 [==============================] - 2s 53ms/step - loss: 0.0741 - accuracy: 0.9822 - val_loss: 0.3405 - val_accuracy: 0.8784
# Epoch 12/20
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0658 - accuracy: 0.9831 - val_loss: 0.3566 - val_accuracy: 0.8773
# Epoch 13/20
# 30/30 [==============================] - 2s 53ms/step - loss: 0.0551 - accuracy: 0.9883 - val_loss: 0.4341 - val_accuracy: 0.8635
# Epoch 14/20
# 30/30 [==============================] - 1s 41ms/step - loss: 0.0488 - accuracy: 0.9904 - val_loss: 0.4595 - val_accuracy: 0.8638
# Epoch 15/20
# 30/30 [==============================] - 1s 42ms/step - loss: 0.0426 - accuracy: 0.9918 - val_loss: 0.4272 - val_accuracy: 0.8711
# Epoch 16/20
# 30/30 [==============================] - 1s 41ms/step - loss: 0.0371 - accuracy: 0.9925 - val_loss: 0.4381 - val_accuracy: 0.8722
# Epoch 17/20
# 30/30 [==============================] - 1s 42ms/step - loss: 0.0301 - accuracy: 0.9950 - val_loss: 0.4607 - val_accuracy: 0.8719
# Epoch 18/20
# 30/30 [==============================] - 1s 41ms/step - loss: 0.0289 - accuracy: 0.9945 - val_loss: 0.4806 - val_accuracy: 0.8700
# Epoch 19/20
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0221 - accuracy: 0.9975 - val_loss: 0.5846 - val_accuracy: 0.8590
# Epoch 20/20
# 30/30 [==============================] - 1s 44ms/step - loss: 0.0201 - accuracy: 0.9973 - val_loss: 0.5398 - val_accuracy: 0.8649

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

epochs = range(1,len(acc)+1)

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'r-', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'r-', label='Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %%
model.predict(x_test)
# Out:
# 782/782 [==============================] - 2s 3ms/step
# array([[1.47287445e-02],
#        [9.99976158e-01],
#        [1.62154928e-01],
#        ...,
#        [9.55355412e-04],
#        [1.17290029e-02],
#        [8.16811144e-01]], dtype=float32)

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print('loss={0}, accuracy={1}'.format(test_loss, test_acc))
# Out:
# 782/782 [==============================] - 3s 4ms/step - loss: 0.5898 - accuracy: 0.8551
# loss=0.589754045009613, accuracy=0.8550800085067749
